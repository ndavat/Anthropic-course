# %%
# %pip install requests python-dotenv openai
import os
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
key = os.getenv("HF_TOKEN")
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key = key,
)

completion = client.chat.completions.create(
    model="zai-org/GLM-4.7",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of California?"
        }
    ],
)

print(completion.choices[0].message.content)
# Out:
# The capital of California is **Sacramento**.

# %%
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=key,
)

completion = client.chat.completions.create(
    model="Tesslate/UIGEN-T2-7B:featherless-ai",
    messages=[
        {
            "role": "user",
            "content": "Hey, can you help me write a poem about the ocean?"
        }
    ],
)

print(completion.choices[0].message.content)
# Out:
# Absolutely! Here's a beautiful, poetic ode to the ocean, crafted with your prompt in mind:
#
# Beneath vast blue skies, where waves embrace the shore,
# An endless expanse where sky and sea forevermore.
# Whispers of old winds, salt on salty breath,
# A mirror to the heavens, where sunbeams softly meet.
#
# Amidst its depths, the secrets of the deep reside,
# Where creatures dance beneath the shimmering tide.
# Ancient coral cities, vibrant hues aglow,
# Home to the tiny dancers, the manta, and the glow.
#
# Tides ebb and flow, a timeless rhythmic beat,
# Carrying tales of storms and gentle morning light.
# Along its edges, beaches kiss the cool blue line,
# Where sand and water blend, a world so pure and fine.
#
# Yet, oh, how fragile this great watery home!
# Polluted whispers, warming currents, storms unknown.
# But still it calls, inviting hearts to roam,
# A symbol of resilience, hope, and boundless room.
#
# So let us cherish this ocean’s grandeur bright,
# ...

# %% [markdown]
# target laptop chois spain capital the comprettion print hole clire temperature stream markdobn yellow blue
