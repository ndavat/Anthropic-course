# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.0

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Handler\": \"index.lambda_handler\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Timeout\": 300,\n  \"MemorySize\": 512,\n  \"Environment\": {\n    \"Variables\": {\n      \"S3_BUCKET_NAME\": \"my-bucket\"\n    }\n  },\n  \"EventInvokeConfig\": {\n    \"MaximumEventAge\": 300,\n    \"MaximumRetryAttempts\": 2\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration for an AWS Lambda function that processes S3 bucket events with a 5-minute timeout and 512 MB memory allocation",
#       "format": "json",
#       "solution_criteria": "Valid JSON with Lambda function configuration including timeout set to 300 seconds, memory set to 512, and event source mapping for S3"
#     },
#     "score": 8.0,
#     "reasoning": "The solution provides a valid and well-structured Lambda function configuration with correct timeout and memory settings. However, it fails to fully meet the criteria requirement for 'event source mapping for S3.' The configuration defines the Lambda function itself but omits the critical S3 event notification setup (S3 bucket trigger, SNS/SQS topic, or EventBridge rule) needed to actually process S3 bucket events. This is a significant gap for the stated use case."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom typing import Set\n\ndef extract_ec2_instance_ids(log_event: dict) -> Set[str]:\n    \"\"\"\n    Extracts all unique EC2 instance IDs from a CloudWatch log event.\n    \n    Args:\n        log_event: CloudWatch log event dictionary containing log messages\n        \n    Returns:\n        Set of unique EC2 instance IDs found in the log messages\n    \"\"\"\n    instance_ids = set()\n    \n    pattern = r'i-[0-9a-f]{8}(?:[0-9a-f]{9})?'\n    \n    if isinstance(log_event, dict):\n        if 'logEvents' in log_event:\n            for event in log_event['logEvents']:\n                message = event.get('message', '')\n                matches = re.findall(pattern, message)\n                instance_ids.update(matches)\n        elif 'message' in log_event:\n            message = log_event.get('message', '')\n            matches = re.findall(pattern, message)\n            instance_ids.update(matches)\n        else:\n            for value in log_event.values():\n                if isinstance(value, str):\n                    matches = re.findall(pattern, value)\n                    instance_ids.update(matches)\n    elif isinstance(log_event, str):\n        matches = re.findall(pattern, log_event)\n        instance_ids.update(matches)\n    \n    return instance_ids\n\n\nif __name__ == \"__main__\":\n    test_event = {\n        \"logEvents\": [\n            {\"message\": \"Instance i-1234567890abcdef0 started successfully\"},\n            {\"message\": \"Instance i-0abcdef1234567890 encountered an error\"},\n            {\"message\": \"Instance i-1234567890abcdef0 is still running\"}\n        ]\n    }\n    \n    result = extract_ec2_instance_ids(test_event)\n    print(json.dumps(sorted(list(result)), indent=2))\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS CloudWatch log event and extracts all unique EC2 instance IDs from the log messages using regex pattern matching",
#       "format": "python",
#       "solution_criteria": "Function accepts a log event string, uses regex to find instance IDs matching pattern 'i-' followed by 17 alphanumeric characters, returns a set of unique IDs"
#     },
#     "score": 8.5,
#     "reasoning": "The solution demonstrates good understanding of regex and handles the core task well. However, there's a mismatch between the regex pattern and the stated criteria regarding exact character count. The pattern's flexibility is a double-edged sword - while it handles edge cases, it also enables loose input validation. The function works correctly for the provided test case and typical CloudWatch events, but the pattern interpretation and error handling could be more precise."
#   },
#   {
#     "output": "\n^[a-z0-9]([a-z0-9-]{0,61}[a-z0-9])?$\n",
#     "test_case": {
#       "task": "Create a regex pattern that validates AWS S3 bucket names according to AWS naming rules (3-63 characters, lowercase letters/numbers/hyphens only, no consecutive hyphens, no leading/trailing hyphens)",
#       "format": "regex",
#       "solution_criteria": "Regex pattern correctly validates S3 bucket names with all constraints: length, character set, no consecutive or leading/trailing hyphens"
#     },
#     "score": 7.5,
#     "reasoning": "The pattern successfully validates the character set and length constraints (3-63 chars via the optional group logic), and correctly prevents leading/trailing hyphens. However, it has a critical flaw: it does not block consecutive hyphens. For example, 'my--bucket' would incorrectly match because the middle section `[a-z0-9-]{0,61}` allows any sequence of hyphens. A corrected pattern would need a negative lookahead like `^(?!.*--)` or use alternation to prevent consecutive hyphens. The optional group design is also unnecessarily convoluted compared to simpler alternatives."
#   }
# ]
